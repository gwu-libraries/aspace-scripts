# %% [markdown]
# # to do:
# - DONE: Paginate
# - DONE: Figure out what's up with Mutual CSV formatting issues (avoided the issue by cutting off at 1,000 characters)
# - DONE: Remove extra lines in the CSV
# - DONE: Search only for collections (aka, "resources") and items within collections (aka, "archival records")
# - Check to see if assumptions about notes aren't correct

# %%
# Import some stuff you'll use
import requests
import json
import csv
import pprint

# %% [markdown]
# # Change these: Add your credentials

# %%
USER = '#'
PASS = '#'
HOST = '#' #don't end with a slash
def aspace_auth(host, username, password):
    auth = requests.post(HOST + '/users/' + username + '/login',
                        params={'password' : password})
    if auth.status_code == 200:
        token = auth.json()['session']
        headers = {'X-ArchivesSpace-Session': token}
        return(headers)
    else:
        return(False)

headers = aspace_auth(HOST, USER, PASS)
print(headers)
# Out:
# {'X-ArchivesSpace-Session': '7233d81e7e09289575be2a7b3f8087e8faf275de11da622775c67a3282c59dc5'}

# %% [markdown]
# # Search for any aspace records of any type with a given query term in any notes field

# %%
# CHANGE YOUR SEARCH TERM AND PAGE SIZES HERE!
q = 'holding'
LAST_PAGE = 1

# %%
# Set things up so the filename is based on your search term
filename = "search_for_" + q + ".csv"

# Create and open the file 
f=csv.writer(open(filename, 'w', newline=''),delimiter=',')

#Create the first row of column headers
f.writerow(['uri','title','identifier','external_id','record_type','note_with_search_term','note_type'])
# Out:
# 78

# %%
# LET'S TEST!

#Reset page to "1"
page = 1
page_num = str(page)

#While page is less than whatever you entered above as the value for "LAST_PAGE"
while page <= LAST_PAGE:

    # Here is the actual search we're sending to ArchivesSpace!
    # First we set up the crazy complicated URL for an advanced query of the "notes" field.
    endpoint = '/repositories/2/search?page=' + page_num + '&type[]=archival_object&type[]=resource&aq={"query":{"field":"notes","value":"' + q + '", "jsonmodel_type":"field_query","negated":false,"literal":true}}'
    # Then we send that search up to ArchivesSpace
    results_full = requests.get(HOST + endpoint, headers=headers)
    # Make sure our python script knows to read the JSON results as python data structures.
    results_full=results_full.json()
    
    #Chris, Dolsy, and Rachel stopped here. 
    
    # The results include a bunch of facet & page information at the top, which we want to skip.
    # Below all the facet and page info, are the actual results. 
    # We'll isolate the part of the results that are really the results, excluding the facets & page info. 
    results=results_full['results']

    # Add all the data!
    # For each record returned by the search above . . . 
    for result in results:
        # Define all the fields that you'd like put into the CSV.
        uri = result.get('uri')
        title = result.get('title')
        identifier = result.get('identifier')
        external_id = result.get('external_id')
        record_type = result.get('types')
        aspace_json = json.loads(result.get('json'))
        # Below, we are making the assumption that each record will have the search term in only one note, 
        # and each multi-part note actually only has one subnote 
        # This returns the content of the first note that has the search term.
        # Note for the user of this data: If you don't see the search term as expected, 
        # it may be in the record but not in the spreadsheet, so check ASpace. 
        notes = aspace_json['notes']
        
        for note in notes:
            try:
                subnotes = note.get('subnotes')
                content = subnotes[0]['content']
                #cut off the note content field if it's more than 1,000 characters, and add an elipse at the end
                content = (content[:1000] + '. . . [This note was cut off. Please check ASpace]') if len(content) > 1000 else content
                note_type = note['label']
            except:
                content = note['content'][0]
                #cut off the note content field if it's more than 1,000 characters, and add an elipse at the end
                content = (content[:1000] + '. . . [This note was cut off. Please check ASpace]') if len(content) > 1000 else content
                note_type = note['label']
            if q in content:
                note_with_search_term = content
        f.writerow([uri,title,identifier,external_id,record_type,note_with_search_term,note_type])
    # finally, add 1 to the page so the next time the loop
    # runs it will get the next page
    page = page + 1
    page_num = str(page)
    
# When everything is done, print below the page information
last_page = results_full['last_page']
last_page = str(last_page)
print('Total pages: ' + last_page)
print('Results are saved to: ' + filename)
# Out:
# {'facets': {'facet_dates': {},
#             'facet_fields': {},
#             'facet_intervals': {},
#             'facet_queries': {},
#             'facet_ranges': {}},
#  'first_page': 1,
#  'last_page': 6,
#  'offset_first': 1,
#  'offset_last': 10,
#  'page_size': 10,
#  'results': [{'create_time': '2016-07-06T04:28:05Z',
#               'created_by': 'admin',
#               'date_type_enum_s': ['single'],
#               'external_id': ['160278'],
#               'id': '/repositories/2/archival_objects/292137',
#               'instance_type_enum_s': ['mixed_materials'],
#               'json': '{"lock_version":0,"position":1724,"publish":true,"ref_id":"ref4087_31v","title":"Group '
#                       'of men and women","display_string":"Group of men and '
#                       'women, '
#                       'undated","restrictions_apply":false,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-06T04:28:05Z","system_mtime":"2017-10-17T12:26:56Z","user_mtime":"2016-07-06T04:28:05Z","suppressed":false,"level":"file","jsonmodel_type":"archival_object","external_ids":[{"external_id":"160278","source":"Archivists '
#                       'Toolkit '
#                       'Database::RESOURCE_COMPONENT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-06T04:28:05Z","system_mtime":"2016-07-06T04:28:05Z","user_mtime":"2016-07-06T04:28:05Z","jsonmodel_type":"external_id"}],"subjects":[],"linked_events":[],"extents":[],"dates":[{"lock_version":0,"expression":"undated","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-06T04:28:05Z","system_mtime":"2016-07-06T04:28:05Z","user_mtime":"2016-07-06T04:28:05Z","date_type":"single","label":"creation","jsonmodel_type":"date"}],"external_documents":[],"rights_statements":[],"linked_agents":[],"instances":[{"lock_version":0,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-06T04:28:05Z","system_mtime":"2016-07-06T04:28:05Z","user_mtime":"2016-07-06T04:28:05Z","instance_type":"mixed_materials","jsonmodel_type":"instance","is_representative":false,"sub_container":{"lock_version":0,"indicator_2":"132.8","created_by":"admin","last_modified_by":"admin","create_time":"2017-10-17T13:17:57Z","system_mtime":"2017-10-17T13:17:57Z","user_mtime":"2017-10-17T13:17:57Z","type_2":"Folder","jsonmodel_type":"sub_container","top_container":{"ref":"/repositories/2/top_containers/25644"}},"container":{"type_1":"Box","indicator_1":"8","barcode_1":"Series '
#                       '13 GW: '
#                       '32882018396336","type_2":"Folder","indicator_2":"132.8","container_locations":[{"jsonmodel_type":"container_location","status":"current","start_date":"2016-07-06","system_mtime":"2017-10-17 '
#                       '13:17:45 UTC","user_mtime":"2017-10-17 13:17:45 '
#                       'UTC","ref":"/locations/1","_resolved":{"lock_version":5,"building":"Off-site","title":"Off-site '
#                       '[WRLC: '
#                       'unspecified]","coordinate_1_label":"WRLC","coordinate_1_indicator":"unspecified","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:06:48Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"location","external_ids":[{"external_id":"2","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:15:56Z","system_mtime":"2017-05-18T15:15:56Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"external_id"},{"external_id":"1916","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:16:25Z","system_mtime":"2017-05-18T15:16:25Z","user_mtime":"2017-05-18T15:16:25Z","jsonmodel_type":"external_id"}],"functions":[],"uri":"/locations/1"}}],"lock_version":252}}],"notes":[{"jsonmodel_type":"note_multipart","label":"General '
#                       'note","subnotes":[{"content":"Man holding sign that '
#                       'says: Patton, Boggs + Blow, '
#                       'Unidentified\\n\\n","jsonmodel_type":"note_text","publish":true}],"type":"odd","persistent_id":"095023cdad11a7211eea8695e3bc29c5","publish":true}],"uri":"/repositories/2/archival_objects/292137","repository":{"ref":"/repositories/2"},"resource":{"ref":"/repositories/2/resources/574"},"parent":{"ref":"/repositories/2/archival_objects/290412"},"has_unpublished_ancestor":false}',
#               'jsonmodel_type': 'archival_object',
#               'label_enum_s': ['creation'],
#               'last_modified_by': 'admin',
#               'level': 'file',
#               'level_enum_s': ['file'],
#               'notes': 'General note Man holding sign that says: Patton, Boggs '
#                        '+ Blow, Unidentified\n'
#                        '\n'
#                        ' odd 095023cdad11a7211eea8695e3bc29c5',
#               'primary_type': 'archival_object',
#               'publish': True,
#               'repository': '/repositories/2',
#               'resource': '/repositories/2/resources/574',
#               'source_enum_s': ['Archivists Toolkit '
#                                 'Database::RESOURCE_COMPONENT'],
#               'suppressed': False,
#               'system_generated': False,
#               'system_mtime': '2017-10-17T12:26:56Z',
#               'title': 'Group of men and women, undated',
#               'top_container_uri_u_sstr': ['/repositories/2/top_containers/25644'],
#               'type_1_enum_s': ['Box'],
#               'type_2_enum_s': ['Folder'],
#               'type_enum_s': ['odd'],
#               'types': ['archival_object'],
#               'uri': '/repositories/2/archival_objects/292137',
#               'user_mtime': '2016-07-06T04:28:05Z'},
#              {'create_time': '2016-07-05T21:30:40Z',
#               'created_by': 'admin',
#               'date_type_enum_s': ['single'],
#               'external_id': ['72307'],
#               'id': '/repositories/2/archival_objects/89874',
#               'instance_type_enum_s': ['mixed_materials'],
#               'json': '{"lock_version":0,"position":101,"publish":true,"ref_id":"ref208_slk","title":"No '
#                       'title","display_string":"No title, '
#                       '07/06/1946","restrictions_apply":false,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2017-10-17T12:26:56Z","user_mtime":"2016-07-05T21:30:40Z","suppressed":false,"level":"file","jsonmodel_type":"archival_object","external_ids":[{"external_id":"72307","source":"Archivists '
#                       'Toolkit '
#                       'Database::RESOURCE_COMPONENT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2016-07-05T21:30:40Z","user_mtime":"2016-07-05T21:30:40Z","jsonmodel_type":"external_id"}],"subjects":[],"linked_events":[],"extents":[],"dates":[{"lock_version":0,"expression":"07/06/1946","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2016-07-05T21:30:40Z","user_mtime":"2016-07-05T21:30:40Z","date_type":"single","label":"creation","jsonmodel_type":"date"}],"external_documents":[],"rights_statements":[],"linked_agents":[],"instances":[{"lock_version":0,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2016-07-05T21:30:40Z","user_mtime":"2016-07-05T21:30:40Z","instance_type":"mixed_materials","jsonmodel_type":"instance","is_representative":false,"sub_container":{"lock_version":0,"indicator_2":"7","created_by":"admin","last_modified_by":"admin","create_time":"2017-10-17T12:48:43Z","system_mtime":"2017-10-17T12:48:43Z","user_mtime":"2017-10-17T12:48:43Z","type_2":"Folder","jsonmodel_type":"sub_container","top_container":{"ref":"/repositories/2/top_containers/7614"}},"container":{"type_1":"Box","indicator_1":"7","type_2":"Folder","indicator_2":"7","container_locations":[{"jsonmodel_type":"container_location","status":"current","start_date":"2016-07-05","system_mtime":"2017-10-17 '
#                       '12:48:43 UTC","user_mtime":"2017-10-17 12:48:43 '
#                       'UTC","ref":"/locations/1","_resolved":{"lock_version":5,"building":"Off-site","title":"Off-site '
#                       '[WRLC: '
#                       'unspecified]","coordinate_1_label":"WRLC","coordinate_1_indicator":"unspecified","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:06:48Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"location","external_ids":[{"external_id":"2","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:15:56Z","system_mtime":"2017-05-18T15:15:56Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"external_id"},{"external_id":"1916","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:16:25Z","system_mtime":"2017-05-18T15:16:25Z","user_mtime":"2017-05-18T15:16:25Z","jsonmodel_type":"external_id"}],"functions":[],"uri":"/locations/1"}}],"lock_version":12}}],"notes":[{"jsonmodel_type":"note_multipart","label":"General '
#                       'note","subnotes":[{"content":"shows Truman and '
#                       'unidentified figure with microphones, arguing. Barkley '
#                       'is sitting in between them, holding a large sack '
#                       '\\"Price Controls\\" and asking \\"But Who Is It Always '
#                       'Left Holding The '
#                       'Bag\\"\\n\\n","jsonmodel_type":"note_text","publish":true}],"type":"odd","persistent_id":"1a75edd2be25dbff105f33f7c62a941f","publish":true}],"uri":"/repositories/2/archival_objects/89874","repository":{"ref":"/repositories/2"},"resource":{"ref":"/repositories/2/resources/202"},"has_unpublished_ancestor":false}',
#               'jsonmodel_type': 'archival_object',
#               'label_enum_s': ['creation'],
#               'last_modified_by': 'admin',
#               'level': 'file',
#               'level_enum_s': ['file'],
#               'notes': 'General note shows Truman and unidentified figure with '
#                        'microphones, arguing. Barkley is sitting in between '
#                        'them, holding a large sack "Price Controls" and asking '
#                        '"But Who Is It Always Left Holding The Bag"\n'
#                        '\n'
#                        ' odd 1a75edd2be25dbff105f33f7c62a941f',
#               'primary_type': 'archival_object',
#               'publish': True,
#               'repository': '/repositories/2',
#               'resource': '/repositories/2/resources/202',
#               'source_enum_s': ['Archivists Toolkit '
#                                 'Database::RESOURCE_COMPONENT'],
#               'suppressed': False,
#               'system_generated': False,
#               'system_mtime': '2017-10-17T12:26:56Z',
#               'title': 'No title, 07/06/1946',
#               'top_container_uri_u_sstr': ['/repositories/2/top_containers/7614'],
#               'type_1_enum_s': ['Box'],
#               'type_2_enum_s': ['Folder'],
#               'type_enum_s': ['odd'],
#               'types': ['archival_object'],
#               'uri': '/repositories/2/archival_objects/89874',
#               'user_mtime': '2016-07-05T21:30:40Z'},
#              {'create_time': '2016-07-05T21:30:40Z',
#               'created_by': 'admin',
#               'date_type_enum_s': ['single'],
#               'external_id': ['72357'],
#               'id': '/repositories/2/archival_objects/89824',
#               'instance_type_enum_s': ['mixed_materials'],
#               'json': '{"lock_version":0,"position":51,"publish":true,"ref_id":"ref108_qh1","title":"\\"A '
#                       'Distraction\\"","display_string":"\\"A Distraction\\", '
#                       '03/08/1913","restrictions_apply":false,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2017-10-17T12:26:56Z","user_mtime":"2016-07-05T21:30:40Z","suppressed":false,"level":"file","jsonmodel_type":"archival_object","external_ids":[{"external_id":"72357","source":"Archivists '
#                       'Toolkit '
#                       'Database::RESOURCE_COMPONENT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2016-07-05T21:30:40Z","user_mtime":"2016-07-05T21:30:40Z","jsonmodel_type":"external_id"}],"subjects":[],"linked_events":[],"extents":[],"dates":[{"lock_version":0,"expression":"03/08/1913","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2016-07-05T21:30:40Z","user_mtime":"2016-07-05T21:30:40Z","date_type":"single","label":"creation","jsonmodel_type":"date"}],"external_documents":[],"rights_statements":[],"linked_agents":[],"instances":[{"lock_version":0,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2016-07-05T21:30:40Z","user_mtime":"2016-07-05T21:30:40Z","instance_type":"mixed_materials","jsonmodel_type":"instance","is_representative":false,"sub_container":{"lock_version":0,"indicator_2":"5","created_by":"admin","last_modified_by":"admin","create_time":"2017-10-17T12:48:43Z","system_mtime":"2017-10-17T12:48:43Z","user_mtime":"2017-10-17T12:48:43Z","type_2":"Folder","jsonmodel_type":"sub_container","top_container":{"ref":"/repositories/2/top_containers/7611"}},"container":{"type_1":"Box","indicator_1":"4","type_2":"Folder","indicator_2":"5","container_locations":[{"jsonmodel_type":"container_location","status":"current","start_date":"2016-07-05","system_mtime":"2017-10-17 '
#                       '12:48:43 UTC","user_mtime":"2017-10-17 12:48:43 '
#                       'UTC","ref":"/locations/1","_resolved":{"lock_version":5,"building":"Off-site","title":"Off-site '
#                       '[WRLC: '
#                       'unspecified]","coordinate_1_label":"WRLC","coordinate_1_indicator":"unspecified","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:06:48Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"location","external_ids":[{"external_id":"2","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:15:56Z","system_mtime":"2017-05-18T15:15:56Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"external_id"},{"external_id":"1916","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:16:25Z","system_mtime":"2017-05-18T15:16:25Z","user_mtime":"2017-05-18T15:16:25Z","jsonmodel_type":"external_id"}],"functions":[],"uri":"/locations/1"}}],"lock_version":7}}],"notes":[{"jsonmodel_type":"note_multipart","label":"General '
#                       'note","subnotes":[{"content":"shows William J. Bryan '
#                       'holding off applications for positions to look at '
#                       "Cuba's amnesty "
#                       'bill\\n\\n","jsonmodel_type":"note_text","publish":true}],"type":"odd","persistent_id":"0d84068e49c786295d2bde1ebbc6a5b9","publish":true}],"uri":"/repositories/2/archival_objects/89824","repository":{"ref":"/repositories/2"},"resource":{"ref":"/repositories/2/resources/202"},"has_unpublished_ancestor":false}',
#               'jsonmodel_type': 'archival_object',
#               'label_enum_s': ['creation'],
#               'last_modified_by': 'admin',
#               'level': 'file',
#               'level_enum_s': ['file'],
#               'notes': 'General note shows William J. Bryan holding off '
#                        "applications for positions to look at Cuba's amnesty "
#                        'bill\n'
#                        '\n'
#                        ' odd 0d84068e49c786295d2bde1ebbc6a5b9',
#               'primary_type': 'archival_object',
#               'publish': True,
#               'repository': '/repositories/2',
#               'resource': '/repositories/2/resources/202',
#               'source_enum_s': ['Archivists Toolkit '
#                                 'Database::RESOURCE_COMPONENT'],
#               'suppressed': False,
#               'system_generated': False,
#               'system_mtime': '2017-10-17T12:26:56Z',
#               'title': '"A Distraction", 03/08/1913',
#               'top_container_uri_u_sstr': ['/repositories/2/top_containers/7611'],
#               'type_1_enum_s': ['Box'],
#               'type_2_enum_s': ['Folder'],
#               'type_enum_s': ['odd'],
#               'types': ['archival_object'],
#               'uri': '/repositories/2/archival_objects/89824',
#               'user_mtime': '2016-07-05T21:30:40Z'},
#              {'create_time': '2016-07-05T21:30:41Z',
#               'created_by': 'admin',
#               'date_type_enum_s': ['single'],
#               'external_id': ['72269'],
#               'id': '/repositories/2/archival_objects/89912',
#               'instance_type_enum_s': ['mixed_materials'],
#               'json': '{"lock_version":0,"position":139,"publish":true,"ref_id":"ref284_qyi","title":"\\"Some '
#                       "of Yesteryear's Rabbits Are Busy "
#                       'Again\\"","display_string":"\\"Some of Yesteryear\'s '
#                       'Rabbits Are Busy Again\\", '
#                       '03/28/1948","restrictions_apply":false,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:41Z","system_mtime":"2017-10-17T12:26:56Z","user_mtime":"2016-07-05T21:30:41Z","suppressed":false,"level":"file","jsonmodel_type":"archival_object","external_ids":[{"external_id":"72269","source":"Archivists '
#                       'Toolkit '
#                       'Database::RESOURCE_COMPONENT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:41Z","system_mtime":"2016-07-05T21:30:41Z","user_mtime":"2016-07-05T21:30:41Z","jsonmodel_type":"external_id"}],"subjects":[],"linked_events":[],"extents":[],"dates":[{"lock_version":0,"expression":"03/28/1948","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:41Z","system_mtime":"2016-07-05T21:30:41Z","user_mtime":"2016-07-05T21:30:41Z","date_type":"single","label":"creation","jsonmodel_type":"date"}],"external_documents":[],"rights_statements":[],"linked_agents":[],"instances":[{"lock_version":0,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:41Z","system_mtime":"2016-07-05T21:30:41Z","user_mtime":"2016-07-05T21:30:41Z","instance_type":"mixed_materials","jsonmodel_type":"instance","is_representative":false,"sub_container":{"lock_version":0,"indicator_2":"33","created_by":"admin","last_modified_by":"admin","create_time":"2017-10-17T12:48:44Z","system_mtime":"2017-10-17T12:48:44Z","user_mtime":"2017-10-17T12:48:44Z","type_2":"Folder","jsonmodel_type":"sub_container","top_container":{"ref":"/repositories/2/top_containers/7615"}},"container":{"type_1":"Box","indicator_1":"8","type_2":"Folder","indicator_2":"33","container_locations":[{"jsonmodel_type":"container_location","status":"current","start_date":"2016-07-05","system_mtime":"2017-10-17 '
#                       '12:48:43 UTC","user_mtime":"2017-10-17 12:48:43 '
#                       'UTC","ref":"/locations/1","_resolved":{"lock_version":5,"building":"Off-site","title":"Off-site '
#                       '[WRLC: '
#                       'unspecified]","coordinate_1_label":"WRLC","coordinate_1_indicator":"unspecified","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:06:48Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"location","external_ids":[{"external_id":"2","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:15:56Z","system_mtime":"2017-05-18T15:15:56Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"external_id"},{"external_id":"1916","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:16:25Z","system_mtime":"2017-05-18T15:16:25Z","user_mtime":"2017-05-18T15:16:25Z","jsonmodel_type":"external_id"}],"functions":[],"uri":"/locations/1"}}],"lock_version":39}}],"notes":[{"jsonmodel_type":"note_multipart","label":"General '
#                       'note","subnotes":[{"content":"shows unidentified figure '
#                       'in academic gown being chased by rabbits holding signs '
#                       'which read '
#                       '\\"Ike\\"\\n\\n","jsonmodel_type":"note_text","publish":true}],"type":"odd","persistent_id":"f6cf1438388c273191a75ebc0ec28685","publish":true}],"uri":"/repositories/2/archival_objects/89912","repository":{"ref":"/repositories/2"},"resource":{"ref":"/repositories/2/resources/202"},"has_unpublished_ancestor":false}',
#               'jsonmodel_type': 'archival_object',
#               'label_enum_s': ['creation'],
#               'last_modified_by': 'admin',
#               'level': 'file',
#               'level_enum_s': ['file'],
#               'notes': 'General note shows unidentified figure in academic '
#                        'gown being chased by rabbits holding signs which read '
#                        '"Ike"\n'
#                        '\n'
#                        ' odd f6cf1438388c273191a75ebc0ec28685',
#               'primary_type': 'archival_object',
#               'publish': True,
#               'repository': '/repositories/2',
#               'resource': '/repositories/2/resources/202',
#               'source_enum_s': ['Archivists Toolkit '
#                                 'Database::RESOURCE_COMPONENT'],
#               'suppressed': False,
#               'system_generated': False,
#               'system_mtime': '2017-10-17T12:26:56Z',
#               'title': '"Some of Yesteryear\'s Rabbits Are Busy Again", '
#                        '03/28/1948',
#               'top_container_uri_u_sstr': ['/repositories/2/top_containers/7615'],
#               'type_1_enum_s': ['Box'],
#               'type_2_enum_s': ['Folder'],
#               'type_enum_s': ['odd'],
#               'types': ['archival_object'],
#               'uri': '/repositories/2/archival_objects/89912',
#               'user_mtime': '2016-07-05T21:30:41Z'},
#              {'create_time': '2016-07-05T23:42:58Z',
#               'created_by': 'admin',
#               'date_type_enum_s': ['single'],
#               'external_id': ['118662'],
#               'id': '/repositories/2/archival_objects/153277',
#               'instance_type_enum_s': ['mixed_materials'],
#               'json': '{"lock_version":0,"position":5,"publish":true,"ref_id":"ref2685_35i","title":"Credo '
#                       'of a Public Servant","display_string":"Credo of a '
#                       'Public Servant, '
#                       'undated","restrictions_apply":false,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T23:42:58Z","system_mtime":"2017-10-17T12:26:56Z","user_mtime":"2016-07-05T23:42:58Z","suppressed":false,"level":"file","jsonmodel_type":"archival_object","external_ids":[{"external_id":"118662","source":"Archivists '
#                       'Toolkit '
#                       'Database::RESOURCE_COMPONENT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T23:42:58Z","system_mtime":"2016-07-05T23:42:58Z","user_mtime":"2016-07-05T23:42:58Z","jsonmodel_type":"external_id"}],"subjects":[],"linked_events":[],"extents":[],"dates":[{"lock_version":0,"expression":"undated","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T23:42:58Z","system_mtime":"2016-07-05T23:42:58Z","user_mtime":"2016-07-05T23:42:58Z","date_type":"single","label":"creation","jsonmodel_type":"date"}],"external_documents":[],"rights_statements":[],"linked_agents":[],"instances":[{"lock_version":0,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T23:42:58Z","system_mtime":"2016-07-05T23:42:58Z","user_mtime":"2016-07-05T23:42:58Z","instance_type":"mixed_materials","jsonmodel_type":"instance","is_representative":false,"sub_container":{"lock_version":0,"indicator_2":"7","created_by":"admin","last_modified_by":"admin","create_time":"2017-10-17T12:58:16Z","system_mtime":"2017-10-17T12:58:16Z","user_mtime":"2017-10-17T12:58:16Z","type_2":"Folder","jsonmodel_type":"sub_container","top_container":{"ref":"/repositories/2/top_containers/12992"}},"container":{"type_1":"Box","indicator_1":"255","barcode_1":"GW: '
#                       '32882016581483","type_2":"Folder","indicator_2":"7","container_locations":[{"jsonmodel_type":"container_location","status":"current","start_date":"2016-07-05","system_mtime":"2017-10-17 '
#                       '12:58:16 UTC","user_mtime":"2017-10-17 12:58:16 '
#                       'UTC","ref":"/locations/1","_resolved":{"lock_version":5,"building":"Off-site","title":"Off-site '
#                       '[WRLC: '
#                       'unspecified]","coordinate_1_label":"WRLC","coordinate_1_indicator":"unspecified","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:06:48Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"location","external_ids":[{"external_id":"2","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:15:56Z","system_mtime":"2017-05-18T15:15:56Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"external_id"},{"external_id":"1916","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:16:25Z","system_mtime":"2017-05-18T15:16:25Z","user_mtime":"2017-05-18T15:16:25Z","jsonmodel_type":"external_id"}],"functions":[],"uri":"/locations/1"}}],"lock_version":16}}],"notes":[{"jsonmodel_type":"note_multipart","label":"General '
#                       'note","subnotes":[{"content":"Printed like a '
#                       'certificate, this is a credo for people holding a '
#                       'government '
#                       'post\\n\\n","jsonmodel_type":"note_text","publish":true}],"type":"odd","persistent_id":"426758a12954196855377985f66d89a2","publish":true}],"uri":"/repositories/2/archival_objects/153277","repository":{"ref":"/repositories/2"},"resource":{"ref":"/repositories/2/resources/305"},"parent":{"ref":"/repositories/2/archival_objects/153271"},"has_unpublished_ancestor":false}',
#               'jsonmodel_type': 'archival_object',
#               'label_enum_s': ['creation'],
#               'last_modified_by': 'admin',
#               'level': 'file',
#               'level_enum_s': ['file'],
#               'notes': 'General note Printed like a certificate, this is a '
#                        'credo for people holding a government post\n'
#                        '\n'
#                        ' odd 426758a12954196855377985f66d89a2',
#               'primary_type': 'archival_object',
#               'publish': True,
#               'repository': '/repositories/2',
#               'resource': '/repositories/2/resources/305',
#               'source_enum_s': ['Archivists Toolkit '
#                                 'Database::RESOURCE_COMPONENT'],
#               'suppressed': False,
#               'system_generated': False,
#               'system_mtime': '2017-10-17T12:26:56Z',
#               'title': 'Credo of a Public Servant, undated',
#               'top_container_uri_u_sstr': ['/repositories/2/top_containers/12992'],
#               'type_1_enum_s': ['Box'],
#               'type_2_enum_s': ['Folder'],
#               'type_enum_s': ['odd'],
#               'types': ['archival_object'],
#               'uri': '/repositories/2/archival_objects/153277',
#               'user_mtime': '2016-07-05T23:42:58Z'},
#              {'_agents_corporate_entities_735_relator_sort': 'subject',
#               'agent_uris': ['/agents/corporate_entities/735'],
#               'agents': ['National School Boards Association'],
#               'agents_text': ['National School Boards Association'],
#               'create_time': '2016-07-06T03:23:51Z',
#               'created_by': 'admin',
#               'date_type_enum_s': ['inclusive'],
#               'external_id': ['339136'],
#               'id': '/repositories/2/archival_objects/258428',
#               'instance_type_enum_s': ['graphic_materials'],
#               'json': '{"lock_version":0,"position":71,"publish":true,"ref_id":"ref81_j4n","component_id":"Series '
#                       '6","title":"Publication '
#                       'Photos","display_string":"Publication Photos, April '
#                       '1970","restrictions_apply":false,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-06T03:23:51Z","system_mtime":"2017-10-26T13:19:51Z","user_mtime":"2016-07-06T03:23:51Z","suppressed":false,"level":"file","jsonmodel_type":"archival_object","external_ids":[{"external_id":"339136","source":"Archivists '
#                       'Toolkit '
#                       'Database::RESOURCE_COMPONENT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-06T03:23:51Z","system_mtime":"2016-07-06T03:23:51Z","user_mtime":"2016-07-06T03:23:51Z","jsonmodel_type":"external_id"}],"subjects":[{"ref":"/subjects/992","_resolved":{"lock_version":1,"title":"Scotia '
#                       '(N.Y.)","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:08:35Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2016-07-05T15:08:35Z","source":"lcsh","jsonmodel_type":"subject","external_ids":[{"external_id":"1323","source":"Archivists '
#                       'Toolkit '
#                       'Database::SUBJECT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:08:35Z","system_mtime":"2016-07-05T15:08:35Z","user_mtime":"2016-07-05T15:08:35Z","jsonmodel_type":"external_id"}],"publish":true,"terms":[{"lock_version":0,"term":"Scotia '
#                       '(N.Y.)","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:08:35Z","system_mtime":"2016-07-05T15:08:35Z","user_mtime":"2016-07-05T15:08:35Z","term_type":"geographic","jsonmodel_type":"term","uri":"/terms/978","vocabulary":"/vocabularies/1"}],"external_documents":[],"uri":"/subjects/992","is_linked_to_published_record":true,"vocabulary":"/vocabularies/1"}},{"ref":"/subjects/993","_resolved":{"lock_version":1,"title":"Sheridan '
#                       '(Wyo.)","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:08:35Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2016-07-05T15:08:35Z","source":"lcsh","jsonmodel_type":"subject","external_ids":[{"external_id":"1324","source":"Archivists '
#                       'Toolkit '
#                       'Database::SUBJECT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:08:35Z","system_mtime":"2016-07-05T15:08:35Z","user_mtime":"2016-07-05T15:08:35Z","jsonmodel_type":"external_id"}],"publish":true,"terms":[{"lock_version":0,"term":"Sheridan '
#                       '(Wyo.)","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:08:35Z","system_mtime":"2016-07-05T15:08:35Z","user_mtime":"2016-07-05T15:08:35Z","term_type":"geographic","jsonmodel_type":"term","uri":"/terms/979","vocabulary":"/vocabularies/1"}],"external_documents":[],"uri":"/subjects/993","is_linked_to_published_record":true,"vocabulary":"/vocabularies/1"}}],"linked_events":[],"extents":[],"dates":[{"lock_version":0,"expression":"April '
#                       '1970","begin":"1970","end":"1970","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-06T03:23:51Z","system_mtime":"2016-07-06T03:23:51Z","user_mtime":"2016-07-06T03:23:51Z","date_type":"inclusive","label":"creation","jsonmodel_type":"date"}],"external_documents":[],"rights_statements":[],"linked_agents":[{"role":"subject","terms":[],"ref":"/agents/corporate_entities/735","_resolved":{"lock_version":3,"publish":false,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:12:28Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2016-07-05T15:12:28Z","jsonmodel_type":"agent_corporate_entity","agent_contacts":[{"lock_version":0,"name":"National '
#                       'School Boards '
#                       'Association","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:12:28Z","system_mtime":"2016-07-05T15:12:28Z","user_mtime":"2016-07-05T15:12:28Z","jsonmodel_type":"agent_contact","telephones":[]}],"linked_agent_roles":["subject"],"external_documents":[],"rights_statements":[],"notes":[],"dates_of_existence":[],"names":[{"lock_version":0,"primary_name":"National '
#                       'School Boards Association","sort_name":"National School '
#                       'Boards '
#                       'Association","sort_name_auto_generate":true,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:12:28Z","system_mtime":"2016-07-05T15:12:28Z","user_mtime":"2016-07-05T15:12:28Z","authorized":true,"is_display_name":true,"source":"naf","rules":"aacr","jsonmodel_type":"name_corporate_entity","use_dates":[]}],"related_agents":[],"uri":"/agents/corporate_entities/735","agent_type":"agent_corporate_entity","display_name":{"lock_version":0,"primary_name":"National '
#                       'School Boards Association","sort_name":"National School '
#                       'Boards '
#                       'Association","sort_name_auto_generate":true,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:12:28Z","system_mtime":"2016-07-05T15:12:28Z","user_mtime":"2016-07-05T15:12:28Z","authorized":true,"is_display_name":true,"source":"naf","rules":"aacr","jsonmodel_type":"name_corporate_entity","use_dates":[]},"title":"National '
#                       'School Boards '
#                       'Association","is_linked_to_published_record":true}}],"instances":[{"lock_version":0,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-06T03:23:51Z","system_mtime":"2016-07-06T03:23:51Z","user_mtime":"2016-07-06T03:23:51Z","instance_type":"graphic_materials","jsonmodel_type":"instance","is_representative":false,"sub_container":{"lock_version":0,"indicator_2":"8","created_by":"admin","last_modified_by":"admin","create_time":"2017-10-17T13:13:51Z","system_mtime":"2017-10-17T13:13:51Z","user_mtime":"2017-10-17T13:13:51Z","type_2":"Folder","jsonmodel_type":"sub_container","top_container":{"ref":"/repositories/2/top_containers/23716"}},"container":{"type_1":"Box","indicator_1":"3053","type_2":"Folder","indicator_2":"8","container_locations":[{"jsonmodel_type":"container_location","status":"current","start_date":"2016-07-05","system_mtime":"2017-10-17 '
#                       '13:13:51 UTC","user_mtime":"2017-10-17 13:13:51 '
#                       'UTC","ref":"/locations/1","_resolved":{"lock_version":5,"building":"Off-site","title":"Off-site '
#                       '[WRLC: '
#                       'unspecified]","coordinate_1_label":"WRLC","coordinate_1_indicator":"unspecified","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:06:48Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"location","external_ids":[{"external_id":"2","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:15:56Z","system_mtime":"2017-05-18T15:15:56Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"external_id"},{"external_id":"1916","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:16:25Z","system_mtime":"2017-05-18T15:16:25Z","user_mtime":"2017-05-18T15:16:25Z","jsonmodel_type":"external_id"}],"functions":[],"uri":"/locations/1"}}],"lock_version":43}}],"notes":[{"jsonmodel_type":"note_multipart","label":"Scope '
#                       'and Contents","subnotes":[{"content":"Contains a photo '
#                       'of a woman holding a sign that says \\"100% '
#                       'Unified\\"","jsonmodel_type":"note_text","publish":true}],"type":"scopecontent","persistent_id":"dea150edc54716cce271ea10cf4202ee","publish":true}],"uri":"/repositories/2/archival_objects/258428","repository":{"ref":"/repositories/2"},"resource":{"ref":"/repositories/2/resources/557"},"parent":{"ref":"/repositories/2/archival_objects/258356"},"has_unpublished_ancestor":false}',
#               'jsonmodel_type': 'archival_object',
#               'label_enum_s': ['creation'],
#               'last_modified_by': 'admin',
#               'level': 'file',
#               'level_enum_s': ['file'],
#               'notes': 'Scope and Contents Contains a photo of a woman holding '
#                        'a sign that says "100% Unified" scopecontent '
#                        'dea150edc54716cce271ea10cf4202ee',
#               'primary_type': 'archival_object',
#               'publish': True,
#               'repository': '/repositories/2',
#               'resource': '/repositories/2/resources/557',
#               'role_enum_s': ['subject'],
#               'rules_enum_s': ['aacr'],
#               'source_enum_s': ['Archivists Toolkit '
#                                 'Database::RESOURCE_COMPONENT'],
#               'subjects': ['Scotia (N.Y.)', 'Sheridan (Wyo.)'],
#               'subjects_text': ['Scotia (N.Y.)', 'Sheridan (Wyo.)'],
#               'summary': 'Contains a photo of a woman holding a sign that says '
#                          '"100% Unified"',
#               'suppressed': False,
#               'system_generated': False,
#               'system_mtime': '2017-10-26T13:19:51Z',
#               'term_type_enum_s': ['geographic'],
#               'title': 'Publication Photos, April 1970',
#               'top_container_uri_u_sstr': ['/repositories/2/top_containers/23716'],
#               'type_1_enum_s': ['Box'],
#               'type_2_enum_s': ['Folder'],
#               'type_enum_s': ['scopecontent'],
#               'types': ['archival_object'],
#               'uri': '/repositories/2/archival_objects/258428',
#               'user_mtime': '2016-07-06T03:23:51Z'},
#              {'create_time': '2016-07-05T21:30:39Z',
#               'created_by': 'admin',
#               'date_type_enum_s': ['single'],
#               'external_id': ['72365'],
#               'id': '/repositories/2/archival_objects/89816',
#               'instance_type_enum_s': ['mixed_materials'],
#               'json': '{"lock_version":0,"position":43,"publish":true,"ref_id":"ref92_0gh","title":"\\"A '
#                       'Spring Caller At The White '
#                       'House\\"","display_string":"\\"A Spring Caller At The '
#                       'White House\\", '
#                       '04/21/1910","restrictions_apply":false,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:39Z","system_mtime":"2017-10-17T12:26:56Z","user_mtime":"2016-07-05T21:30:39Z","suppressed":false,"level":"file","jsonmodel_type":"archival_object","external_ids":[{"external_id":"72365","source":"Archivists '
#                       'Toolkit '
#                       'Database::RESOURCE_COMPONENT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:39Z","system_mtime":"2016-07-05T21:30:39Z","user_mtime":"2016-07-05T21:30:39Z","jsonmodel_type":"external_id"}],"subjects":[],"linked_events":[],"extents":[],"dates":[{"lock_version":0,"expression":"04/21/1910","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:39Z","system_mtime":"2016-07-05T21:30:39Z","user_mtime":"2016-07-05T21:30:39Z","date_type":"single","label":"creation","jsonmodel_type":"date"}],"external_documents":[],"rights_statements":[],"linked_agents":[],"instances":[{"lock_version":0,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:39Z","system_mtime":"2016-07-05T21:30:39Z","user_mtime":"2016-07-05T21:30:39Z","instance_type":"mixed_materials","jsonmodel_type":"instance","is_representative":false,"sub_container":{"lock_version":0,"indicator_2":"12","created_by":"admin","last_modified_by":"admin","create_time":"2017-10-17T12:48:43Z","system_mtime":"2017-10-17T12:48:43Z","user_mtime":"2017-10-17T12:48:43Z","type_2":"Folder","jsonmodel_type":"sub_container","top_container":{"ref":"/repositories/2/top_containers/7610"}},"container":{"type_1":"Box","indicator_1":"3","type_2":"Folder","indicator_2":"12","container_locations":[{"jsonmodel_type":"container_location","status":"current","start_date":"2016-07-05","system_mtime":"2017-10-17 '
#                       '12:48:43 UTC","user_mtime":"2017-10-17 12:48:43 '
#                       'UTC","ref":"/locations/1","_resolved":{"lock_version":5,"building":"Off-site","title":"Off-site '
#                       '[WRLC: '
#                       'unspecified]","coordinate_1_label":"WRLC","coordinate_1_indicator":"unspecified","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:06:48Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"location","external_ids":[{"external_id":"2","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:15:56Z","system_mtime":"2017-05-18T15:15:56Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"external_id"},{"external_id":"1916","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:16:25Z","system_mtime":"2017-05-18T15:16:25Z","user_mtime":"2017-05-18T15:16:25Z","jsonmodel_type":"external_id"}],"functions":[],"uri":"/locations/1"}}],"lock_version":15}}],"notes":[{"jsonmodel_type":"note_multipart","label":"General '
#                       'note","subnotes":[{"content":"shows William H. Taft '
#                       'holding a bouquet given to him from William R. Hearst, '
#                       'as teddy bear '
#                       'watches\\n\\n","jsonmodel_type":"note_text","publish":true}],"type":"odd","persistent_id":"6472e004850298497206886d8ccd2690","publish":true}],"uri":"/repositories/2/archival_objects/89816","repository":{"ref":"/repositories/2"},"resource":{"ref":"/repositories/2/resources/202"},"has_unpublished_ancestor":false}',
#               'jsonmodel_type': 'archival_object',
#               'label_enum_s': ['creation'],
#               'last_modified_by': 'admin',
#               'level': 'file',
#               'level_enum_s': ['file'],
#               'notes': 'General note shows William H. Taft holding a bouquet '
#                        'given to him from William R. Hearst, as teddy bear '
#                        'watches\n'
#                        '\n'
#                        ' odd 6472e004850298497206886d8ccd2690',
#               'primary_type': 'archival_object',
#               'publish': True,
#               'repository': '/repositories/2',
#               'resource': '/repositories/2/resources/202',
#               'source_enum_s': ['Archivists Toolkit '
#                                 'Database::RESOURCE_COMPONENT'],
#               'suppressed': False,
#               'system_generated': False,
#               'system_mtime': '2017-10-17T12:26:56Z',
#               'title': '"A Spring Caller At The White House", 04/21/1910',
#               'top_container_uri_u_sstr': ['/repositories/2/top_containers/7610'],
#               'type_1_enum_s': ['Box'],
#               'type_2_enum_s': ['Folder'],
#               'type_enum_s': ['odd'],
#               'types': ['archival_object'],
#               'uri': '/repositories/2/archival_objects/89816',
#               'user_mtime': '2016-07-05T21:30:39Z'},
#              {'create_time': '2016-07-05T21:30:40Z',
#               'created_by': 'admin',
#               'date_type_enum_s': ['single'],
#               'external_id': ['72354'],
#               'id': '/repositories/2/archival_objects/89827',
#               'instance_type_enum_s': ['mixed_materials'],
#               'json': '{"lock_version":0,"position":54,"publish":true,"ref_id":"ref114_zv9","title":"No '
#                       'title","display_string":"No title, '
#                       '07/05/1917","restrictions_apply":false,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2017-10-17T12:26:56Z","user_mtime":"2016-07-05T21:30:40Z","suppressed":false,"level":"file","jsonmodel_type":"archival_object","external_ids":[{"external_id":"72354","source":"Archivists '
#                       'Toolkit '
#                       'Database::RESOURCE_COMPONENT","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2016-07-05T21:30:40Z","user_mtime":"2016-07-05T21:30:40Z","jsonmodel_type":"external_id"}],"subjects":[],"linked_events":[],"extents":[],"dates":[{"lock_version":0,"expression":"07/05/1917","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2016-07-05T21:30:40Z","user_mtime":"2016-07-05T21:30:40Z","date_type":"single","label":"creation","jsonmodel_type":"date"}],"external_documents":[],"rights_statements":[],"linked_agents":[],"instances":[{"lock_version":0,"created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T21:30:40Z","system_mtime":"2016-07-05T21:30:40Z","user_mtime":"2016-07-05T21:30:40Z","instance_type":"mixed_materials","jsonmodel_type":"instance","is_representative":false,"sub_container":{"lock_version":0,"indicator_2":"1","created_by":"admin","last_modified_by":"admin","create_time":"2017-10-17T12:48:43Z","system_mtime":"2017-10-17T12:48:43Z","user_mtime":"2017-10-17T12:48:43Z","type_2":"Folder","jsonmodel_type":"sub_container","top_container":{"ref":"/repositories/2/top_containers/7612"}},"container":{"type_1":"Box","indicator_1":"5","type_2":"Folder","indicator_2":"1","container_locations":[{"jsonmodel_type":"container_location","status":"current","start_date":"2016-07-05","system_mtime":"2017-10-17 '
#                       '12:48:43 UTC","user_mtime":"2017-10-17 12:48:43 '
#                       'UTC","ref":"/locations/1","_resolved":{"lock_version":5,"building":"Off-site","title":"Off-site '
#                       '[WRLC: '
#                       'unspecified]","coordinate_1_label":"WRLC","coordinate_1_indicator":"unspecified","created_by":"admin","last_modified_by":"admin","create_time":"2016-07-05T15:06:48Z","system_mtime":"2017-10-17T12:27:25Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"location","external_ids":[{"external_id":"2","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:15:56Z","system_mtime":"2017-05-18T15:15:56Z","user_mtime":"2017-05-18T15:15:56Z","jsonmodel_type":"external_id"},{"external_id":"1916","source":"Archivists '
#                       'Toolkit '
#                       'Database::LOCATION","created_by":"admin","last_modified_by":"admin","create_time":"2017-05-18T15:16:25Z","system_mtime":"2017-05-18T15:16:25Z","user_mtime":"2017-05-18T15:16:25Z","jsonmodel_type":"external_id"}],"functions":[],"uri":"/locations/1"}}],"lock_version":20}}],"notes":[{"jsonmodel_type":"note_multipart","label":"General '
#                       'note","subnotes":[{"content":"shows John Bull holding '
# ...
#                        'reliance on telephone lines for the broadcast '
#                        "industry's transmission capacity.[87] In 1979, Amway "
#                        'purchased WCFL from the Chicago Federation of Labor to '
#                        "serve as Mutual's flagship. For the first time, the "
#                        'network that had been founded by radio stations '
#                        'directly controlled a station of its own, and in one '
#                        "of the country's largest markets. Mutual also reached "
#                        'its greatest number of affiliates that year—950. This '
#                        'was fewer than ABC, whose multipronged approach had '
#                        'proven very successful, but far in front of NBC and '
#                        'CBS.[88] It appeared that Amway was ready to pose a '
#                        'major challenge to the industry leaders.\n'
#                        '\n'
#                        ' Programming: Rise of the call-in talk show One of the '
#                        'few primary network programs outside of news and '
#                        'sports that Mutual initiated during this era became '
#                        'one of the most successful in its history: the first '
#                        'nationwide, all-night call-in show, which launched on '
#                        'November 3, 1975, with Herb Jepko as host. Jepko, who '
#                        'had run a telephone talk show out of KSL in Salt Lake '
#                        'City for years, so determinedly avoided controversy '
#                        'that some callers simply talked about the weather '
#                        'where they lived. Jepko was briefly succeeded by Long '
#                        'John Nebel, before Mutual tapped a local talk show '
#                        'host at WIOD in Miami. Larry King made his network '
#                        'premiere on January 30, 1978; by the turn of the '
#                        'decade, he was being carried by 150 stations and '
#                        'credited with attracting many new affiliates to '
#                        'Mutual.[89] King continued his MBS call-in show for '
#                        'years, even as he began appearing on television in the '
#                        'mid-1980s. From 1970 through 1977, Mutual was the '
#                        'national radio broadcaster for Monday Night Football.\n'
#                        '\n'
#                        ' 1980s–1990s: The end of Mutual In 1980, Amway '
#                        'purchased WHN in New York, giving Mutual a second '
#                        'major-market owned-and-operated station. At the '
#                        'beginning of the year, MBS had started airing Mutual '
#                        'Radio Theater, a renamed version of Sears Radio '
#                        'Theater, which it had just picked up. A number of '
#                        'well-regarded dramas were produced as party of the '
#                        'anthology series.[90] In 1981, Mutual launched Dick '
#                        "Clark's National Music Survey, a three-hour-long "
#                        'weekly program combining music and interviews. Despite '
#                        'these developments and the fact that its satellite '
#                        'network was now fully on line, Amway was making little '
#                        "if any profit out of MBS.[91] The network's corporate "
#                        'parent began backing out of the radio business. Mutual '
#                        "Radio Theater, the network's last ever original "
#                        'dramatic series, had its final show on December 19, '
#                        "1981.[92] In November 1983, Amway sold off Mutual's "
#                        'WCFL flagship to Statewide Broadcasting.[93] A year '
#                        'later, a deal was struck for the sale of WHN to '
#                        'Doubleday Broadcasting.[94] In 1985, a suitor came '
#                        'calling for the network itself.\n'
#                        '\n'
#                        " Ad for Dick Clark's National Music Survey, among the "
#                        'last entertainment shows to originate on '
#                        'Mutual.Westwood One, a major radio production company '
#                        'and syndicator—a budding network, in short—was looking '
#                        'to expand its operations. Westwood and Mutual were a '
#                        'good match: The demographics of Mutual affiliates '
#                        'tended to be adult; most of the stations that bought '
#                        "Westwood's programming, much of it in the pop music "
#                        'field, had substantially younger audiences. Mutual had '
#                        'the news operations that Westwood lacked. And there '
#                        "was Mutual's size; though down from its peak, it still "
#                        'commanded 810 affiliates, a strong second among the '
#                        'Big Four.[95] In September 1985, Amway sold the '
#                        'network to Westwood One for $39 million.[96] "It\'s a '
#                        'perfect fit," declared Westwood head Norman J. Pattiz. '
#                        "Referring to the united company's ability to give "
#                        'advertisers access to a broad demographic sweep, he '
#                        'called it "a classic case of two plus two equaling '
#                        'five."[97] In 1987, the number got even bigger: '
#                        "Westwood One snapped up Mutual's long-time competitor, "
#                        'the NBC Radio Network, for $50 million. With Mutual '
#                        'now part of a much larger programming service, a slow '
#                        'phase out of its identity was perhaps inevitable. In '
#                        '1993, when Larry King switched his radio show to the '
#                        'daytime a year before giving it up, the late-night '
#                        'call-in slot went to WCFL alumnus Jim Bohannon; within '
#                        'a few years, it was a Westwood One–branded show.[98] '
#                        'Westwood One was itself taken over by Infinity '
#                        'Broadcasting in 1994.[99] In a deal announced in June '
#                        "1996 and completed that December, CBS's new parent "
#                        'company, Westinghouse, acquired Infinity for just shy '
#                        'of $5 billion.[100] The direct descendants of the '
#                        'three original U.S. network companies had merged.\n'
#                        '\n'
#                        'At this point, Mutual was little more than a brand '
#                        'name for certain news and sports programming provided '
#                        "by the new conglomerate's Westwood One division. "
#                        'Mutual and NBC Radio newscasters sat back to back in '
#                        'the Westwood One studio, the former main MBS facility '
#                        'in Crystal City, Virginia.[101] In April 1999, '
#                        'Westwood One announced it was dropping the Mutual '
#                        'brand in favor of CNN Radio—yet another acquisition. A '
#                        'former member of the news team described the end: '
#                        '"Official time of Mutual Radio\'s death was Midnight '
#                        '4/17/99. No tribute, no mention it was the last '
#                        'newscast...it just died."[102] The Crystal City '
#                        "facility was closed in March 2001, and Westwood's "
#                        'primary operations were transferred to the CBS '
#                        'Broadcast Center in New York City.[103] As of early '
#                        '2007, Jim Bohannon was still on the air hosting a '
#                        "call-in show tracing directly back to Herb Jepko's "
#                        '1975 launch on MBS, long after Mutual itself was '
#                        'gone.\n'
#                        '\n'
#                        'Note: this preliminary history has been taken verbatim '
#                        'from an article on Wikipedia '
#                        '(http://en.wikipedia.org/wiki/Mutual_Radio_Network) '
#                        'and is a place-holder until the collection is '
#                        'processed.\n'
#                        '\n'
#                        '  0b43ecfef547d189546b32ee2aad22b3 Collection Scope '
#                        'and Content scopecontent The Mutual Broadcasting '
#                        'System, Inc. records contain more than 40,000 sound '
#                        'recordings, primarily in audiocassette and '
#                        'reel-to-reel audiotape format, as well as scripts and '
#                        'other supporting documents generated by the various '
#                        'shows produced by the Mutual Broadcasting System from '
#                        "the 1950's through the 1990's, including the Jim "
#                        'Bohannon show, 1993-2000 ; America this week, '
#                        '1990-2000 ; First light, 1990-2000 ; Mike Walker show, '
#                        '1990-1995 ; The week in review, 1984-2000 ; Seems like '
#                        'yesterday (SLY), 1987-1989 ; Weekend headliners, '
#                        '1987-1999 ; Newsbreakers, 1985-1990 ; America in the '
#                        'morning, 1984-2000 ; The week in review, 1983-1992 ; '
#                        'Larry King show, 1980-[199-?] ; Mutual Broadcasting '
#                        'series, 1980-1999 ; NBC extra, 1980-1998 ; Larry King '
#                        'show (Miami years), 1970-1979 ; Mutual Radio '
#                        'theater/Zero hour, 1970-1979 ; and The World today, '
#                        '1958-1982. The collection also includes an extensive '
#                        'collection of phonographic recordings of music that '
#                        'had been played over the MBS, obituaries, and '
#                        'reports.\n'
#                        '\n'
#                        'This collection is not processed. Please see staff for '
#                        'assistance.\n'
#                        '\n'
#                        '  1268d000e4078a528d897e1a9140cdf4 Collection '
#                        'Organization arrangement Collection is organized into '
#                        'multiple series: O.J. Simpson trial, 1994-1998 ; Jim '
#                        'Bohannon show, 1993-2000 ; President Bill Clinton, '
#                        '1993-1998 ; Persian Gulf war, 1991 ; Supreme Court '
#                        'Justice Clarence Thomas hearings, 1991 ; America this '
#                        'week, 1990-2000 ; First light, 1990-2000 ; Mike Walker '
#                        'show, 1990-1995 ; President George Bush, 1989-1992 ; '
#                        'The week in review, 1984-2000 ; Seems like yesterday '
#                        '(SLY), 1987-1989 ; Weekend headliners, 1987-1999 ; '
#                        'Newsbreakers, 1985-1990 ; America in the morning, '
#                        '1984-2000 ; The week in review scripts, 1984-1996 ; '
#                        'The week in review, 1983-1992 ; Iranian Hostages '
#                        'return, 1981 ; President Reagan cabinet confirmation '
#                        'hearings, 1981 ; President Ronald Reagan, 1981-1986 ; '
#                        'Golden reels/Golden cassettes, 1980-1998 ; Golden '
#                        'reels/Golden cassettes finding aids ("Golden Sheets"), '
#                        '1980-1998 ; Larry King show, 1980-[199-?] ; Larry King '
#                        'show program log, 1980-[199-?] ; Mutual Broadcasting '
#                        'series, 1980-1999 ; NBC extra, 1980-1998 ; Political '
#                        'conventions, 1980 ; RKO cut sheets, 1980-1989 ; RKO '
#                        'morgue, 1980-1989 ; The world this morning, 1978-1982 '
#                        '; Reporter roundup, 1976-1988 ; Jackie Robinson, Women '
#                        'in the military, and Miscellaneous tapes, [ca. '
#                        '1970-1981] ; Larry King show (Miami years), 1970-1979 '
#                        '; Miscellaneous unlabeled tapes, 1970-1989 ; Mutual '
#                        'Radio theater/Zero hour, 1970-1979 ; Special events, '
#                        '1963-1998 ; Political/Historical events, 1960-1985 ; '
#                        'The World today, 1958-1982 ; NBC sound bites ; '
#                        'Obituaries ; Source reports ; Phonograph collection.\n'
#                        '\n'
#                        '  19ab7b099c7fabe70b8fc475746757bd processinfo '
#                        'Processing time: 7184 hrs.; Size: 1347 Linear feet; '
#                        'Rank: 3  067c97e8d4f245c05a2faa98c797cb31 bib odd Bib '
#                        'records for each series are located in a note at the '
#                        'series level.',
#               'portion_enum_s': ['whole'],
#               'primary_type': 'resource',
#               'publish': True,
#               'relator_enum_s': ['ivr'],
#               'repository': '/repositories/2',
#               'restrictions': 'false',
#               'role_enum_s': ['creator'],
#               'rules_enum_s': ['aacr'],
#               'source_enum_s': ['Archivists Toolkit Database::RESOURCE'],
#               'subjects': ['Phonograph records',
#                            'Audiocassettes',
#                            'Audiotapes',
#                            'Diaries'],
#               'subjects_text': ['Phonograph records',
#                                 'Audiocassettes',
#                                 'Audiotapes',
#                                 'Diaries'],
#               'summary': 'The Mutual Broadcasting System, Inc. records contain '
#                          'more than 40,000 sound recordings, primarily in '
#                          'audiocassette and reel-to-reel audiotape format, as '
#                          'well as scripts and other supporting documents '
#                          'generated by the various shows produced by the '
#                          "Mutual Broadcasting System from the 1950's through "
#                          "the 1990's, including the Jim Bohannon show, "
#                          '1993-2000 ; America this week, 1990-2000 ; First '
#                          'light, 1990-2000 ; Mike Walker show, 1990-1995 ; The '
#                          'week in review, 1984-2000 ; Seems like yesterday '
#                          '(SLY), 1987-1989 ; Weekend headliners, 1987-1999 ; '
#                          'Newsbreakers, 1985-1990 ; America in the morning, '
#                          '1984-2000 ; The week in review, 1983-1992 ; Larry '
#                          'King show, 1980-[199-?] ; Mutual Broadcasting '
#                          'series, 1980-1999 ; NBC extra, 1980-1998 ; Larry '
#                          'King show (Miami years), 1970-1979 ; Mutual Radio '
#                          'theater/Zero hour, 1970-1979 ; and The World today, '
#                          '1958-1982. The collection also includes an extensive '
#                          'collection of phonographic recordings of music that '
#                          'had been played over the MBS, obituaries, and '
#                          'reports.',
#               'suppressed': False,
#               'system_generated': False,
#               'system_mtime': '2018-04-25T15:45:43Z',
#               'term_type_enum_s': ['genre_form'],
#               'title': 'Mutual Broadcasting System, Inc. records',
#               'type_enum_s': ['abstract'],
#               'types': ['resource'],
#               'uri': '/repositories/2/resources/257',
#               'user_mtime': '2018-04-25T15:45:43Z'}],
#  'this_page': 6,
#  'total_hits': 55}
# Total pages: 6
# Results are saved to: search_for_holding.csv

# %% [markdown]
# # ASpace search queries that didn't work.

# %%
query="q:Anything"
search = requests.get(HOST + '/search?', headers=headers, data=query)
search

# %%
endpoint = '/search?page=1&page_size=1&q="/repositories/2"'

results = requests.get(HOST + endpoint, headers=headers)
results
